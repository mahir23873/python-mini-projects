# %%
print("In sha Allah ala Khair")
# Out:
# In sha Allah ala Khair

# %% [markdown]
# ***Python Project - July 2026***

# %%
category = "Food"
amount = 250
payment_type = "Cash"

# %%
categories = ["Food", "Travel", "Rent", "Shopping", "Bills"]

# %%
for item in categories:
    print(item)
# Out:
# Food
# Travel
# Rent
# Shopping
# Bills

# %%
def double_amount(amount):
    return amount * 2

# %%
result = double_amount(250)
print(result)
# Out:
# 500
